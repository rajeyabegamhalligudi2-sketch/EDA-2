# %%
 # import python libraries

import numpy as np #numpy
import pandas as pd #pandas
import matplotlib.pyplot as plt #matplotlib
# %matplotlib inline
import seaborn as sns #seaborn

# %%
df = pd.read_csv('/content/dubai_properties.csv', encoding= 'unicode_escape')

# %%
df.shape # rows x col
# Out:
# (73742, 17)

# %%
df.head()
# Out:
#                                              Address    Rent  Beds  Baths  \
# 0  The Gate Tower 2, The Gate Tower, Shams Gate D...  124000     3      4
# 1                Water's Edge, Yas Island, Abu Dhabi  140000     3      4
# 2            Al Raha Lofts, Al Raha Beach, Abu Dhabi   99000     2      3
# 3  Marina Heights, Marina Square, Al Reem Island,...  220000     3      4
# 4                    West Yas, Yas Island, Abu Dhabi  350000     5      7
#
#         Type  Area_in_sqft  Rent_per_sqft Rent_category Frequency  \
# 0  Apartment          1785      69.467787        Medium    Yearly
# 1  Apartment          1422      98.452883        Medium    Yearly
# 2  Apartment          1314      75.342466        Medium    Yearly
# 3  Penthouse          3843      57.246942          High    Yearly
# 4      Villa          6860      51.020408          High    Yearly
#
#     Furnishing   Purpose Posted_date  Age_of_listing_in_days        Location  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73742 entries, 0 to 73741
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Address                 73742 non-null  object
#  1   Rent                    73742 non-null  int64
#  2   Beds                    73742 non-null  int64
#  3   Baths                   73742 non-null  int64
#  4   Type                    73742 non-null  object
#  5   Area_in_sqft            73742 non-null  int64
#  6   Rent_per_sqft           73742 non-null  float64
#  7   Rent_category           73742 non-null  object
#  8   Frequency               73742 non-null  object
#  9   Furnishing              73742 non-null  object
#  10  Purpose                 73742 non-null  object
#  11  Posted_date             73742 non-null  object
#  12  Age_of_listing_in_days  73742 non-null  int64
#  13  Location                73742 non-null  object
# ...

# %%
df.describe()
# Out:
#                Rent          Beds         Baths   Area_in_sqft  Rent_per_sqft  \
# count  7.374200e+04  73742.000000  73742.000000   73742.000000   73742.000000
# mean   1.479250e+05      2.162811      2.650213    2054.053552      88.057754
# std    3.069658e+05      1.578155      1.632997    3003.919252      66.534400
# min    0.000000e+00      0.000000      1.000000      74.000000       0.000000
# 25%    5.499900e+04      1.000000      2.000000     850.000000      39.977778
# 50%    9.800000e+04      2.000000      2.000000    1334.000000      71.428571
# 75%    1.700000e+05      3.000000      3.000000    2130.000000     118.483412
# max    5.500000e+07     12.000000     11.000000  210254.000000    2182.044888
#
#        Age_of_listing_in_days      Latitude     Longitude
# count            73742.000000  73023.000000  73023.000000
# mean                74.261547     24.918929     55.053133
# std                 72.346767      0.569356      0.653722
# ...

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# Address                     0
# Rent                        0
# Beds                        0
# Baths                       0
# Type                        0
# Area_in_sqft                0
# Rent_per_sqft               0
# Rent_category               0
# Frequency                   0
# Furnishing                  0
# Purpose                     0
# Posted_date                 0
# Age_of_listing_in_days      0
# Location                    0
# City                        0
# Latitude                  719
# Longitude                 719
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
#change data type
df['Rent_per_sqft']= df['Rent_per_sqft'].astype('int') # .astype('int')

# %%
df['Rent_per_sqft'].dtypes # .dtypes
# Out:
# dtype('int64')

# %%
df.columns #.columns
# Out:
# Index(['Address', 'Rent', 'Beds', 'Baths', 'Type', 'Area_in_sqft',
#        'Rent_per_sqft', 'Rent_category', 'Frequency', 'Furnishing', 'Purpose',
#        'Posted_date', 'Age_of_listing_in_days', 'Location', 'City', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
#rename columns
df.rename(columns={'Type':'Stay'}) #rename
# Out:
#                                                  Address    Rent  Beds  Baths  \
# 0      The Gate Tower 2, The Gate Tower, Shams Gate D...  124000     3      4
# 1                    Water's Edge, Yas Island, Abu Dhabi  140000     3      4
# 2                Al Raha Lofts, Al Raha Beach, Abu Dhabi   99000     2      3
# 3      Marina Heights, Marina Square, Al Reem Island,...  220000     3      4
# 4                        West Yas, Yas Island, Abu Dhabi  350000     5      7
# ...                                                  ...     ...   ...    ...
# 73729                          Al Salamah, Umm Al Quwain   10000     0      1
# 73734                           Al Ramlah, Umm Al Quwain   25000     1      1
# 73735                Umm Al Quwain Marina, Umm Al Quwain   22000     2      2
# 73737             Al Huboob 1, Al Salamah, Umm Al Quwain   14000     0      1
# 73738                Umm Al Quwain Marina, Umm Al Quwain   14000     0      1
#
# ...

# %%
df.describe()  #describe()
# Out:
#                Rent          Beds         Baths   Area_in_sqft  Rent_per_sqft  \
# count  7.302300e+04  73023.000000  73023.000000   73023.000000   73023.000000
# mean   1.483723e+05      2.154458      2.638771    2035.634471      88.079276
# std    3.082652e+05      1.571260      1.620881    2976.159891      66.601850
# min    0.000000e+00      0.000000      1.000000      74.000000       0.000000
# 25%    5.499900e+04      1.000000      2.000000     850.000000      40.000000
# 50%    9.800000e+04      2.000000      2.000000    1329.000000      71.000000
# 75%    1.700000e+05      3.000000      3.000000    2101.000000     119.000000
# max    5.500000e+07     12.000000     11.000000  210254.000000    2182.000000
#
#        Age_of_listing_in_days      Latitude     Longitude
# count            73023.000000  73023.000000  73023.000000
# mean                73.884735     24.918929     55.053133
# std                 71.837749      0.569356      0.653722
# ...

# %%
df[['Location','Rent_per_sqft',]].describe() #.describe()
# Out:
#        Rent_per_sqft
# count   73023.000000
# mean       88.079276
# std        66.601850
# min         0.000000
# 25%        40.000000
# 50%        71.000000
# 75%       119.000000
# max      2182.000000

# %%
df[['Location','City',]].describe() #.describe()
# Out:
#               Location   City
# count            73023  73023
# unique             359      8
# top     Al Reem Island  Dubai
# freq              3668  34219

# %%
#Exploratory data analysis -EDA

# %%
df[['Rent','Beds','Baths',]].describe()
# Out:
#                Rent          Beds         Baths
# count  7.302300e+04  73023.000000  73023.000000
# mean   1.483723e+05      2.154458      2.638771
# std    3.082652e+05      1.571260      1.620881
# min    0.000000e+00      0.000000      1.000000
# 25%    5.499900e+04      1.000000      2.000000
# 50%    9.800000e+04      2.000000      2.000000
# 75%    1.700000e+05      3.000000      3.000000
# max    5.500000e+07     12.000000     11.000000

# %%
#plotting a bar chart for Area_in_sqft and its count
#Area_in_sqft

ax = sns.countplot(x='Area_in_sqft', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
dubai_properties = df.groupby(['Furnishing'], as_index=False)['Location'].sum().sort_values(by='Location', ascending=False)
sns.barplot(x='Furnishing', y='Location', data=dubai_properties) #.barplot
# Out:
# <Axes: xlabel='Furnishing', ylabel='Location'>

# %%
# Address
ax=sns.countplot(x='Address', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
# Rent_per_sqft
ax=sns.countplot(x='Rent_per_sqft', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
# Area_in_sqft
ax=sns.countplot(x='Area_in_sqft', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
# Posted_date
ax=sns.countplot(x='Posted_date', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
#Rent _category
ax=sns.countplot(x='Rent_category', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
#Frequency
ax=sns.countplot(x='Frequency', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
#Furnishing
ax=sns.countplot(x='Furnishing', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
# Age_of_list_in_days
ax=sns.countplot(x= 'Age_of_listing_in_days', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
#location
ax=sns.countplot(x= 'Location', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
#city
ax=sns.countplot(x= 'City', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
#latitude
ax=sns.countplot(x= 'Latitude', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
#longitude
ax=sns.countplot(x= 'Longitude', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
#top 10 most Rent sold by Rent_per_sqft

fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Rent')['Rent_per_sqft'].sum(). nlargest(10).sort_values(ascending=False).plot(kind='bar')

# %%
dubai_properties = df.groupby(['Location'], as_index=False)['Rent'].sum().sort_values(by='Rent', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = dubai_properties, x = 'Location',y= 'Rent')

# %%
dubai_properties = df.groupby(['Address'], as_index=False)['Latitude'].sum().sort_values(by='Latitude', ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Address', y='Latitude', data=dubai_properties)

# %%
#Beds and stay_type
ax=sns.countplot(x='Beds', hue = 'Type', data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
# plotting a bar chart for Frequency vs Purpose
dubai_properties = df.groupby(['Frequency'], as_index=False)['Purpose'].sum().sort_values(by='Frequency', ascending=False)
sns.barplot(x = 'Frequency', y='Purpose', data = dubai_properties)

# %%
# total Latitude on bases on top 10 Rent
dubai_properties = df.groupby(['Latitude'], as_index=False)['Rent'].sum().sort_values(by='Rent', ascending=False).head(10)
sns.set(rc ={'figure.figsize':(20,5)})
sns.barplot(x = 'Rent', y='Latitude', data=dubai_properties)

# %%
# total Area_in_sqft and city
dubai_properties = df.groupby((['Area_in_sqft','City']), as_index=False)['City'].sum().sort_values(by='City', ascending=False)
sns.barplot(x = 'Area_in_sqft', y='City', data = dubai_prperties)

# %%
#Address based on Rent and Rent_per_sqft
dubai_Address_Rent_Rent_per_sqft = df.groupby(['Address', 'Rent'], as_index=False)['Rent_per_sqft'].sum().sort_values(by='Rent_per_sqft', ascending=False)
sns.barplot(x='Address', y='Rent', hue='Rent_per_sqft', data=dubai_Address_Rent_Rent_per-sqft)
plt.title('Total Address based on Rent and Rent_per_sqft')
plt.xlabel('Address')
plt.ylabel('Total Rent')
plt.show()

# %%
dubai_Latitude_Location = df.groupby(['Latitude', 'Location'], as_index=False)['Location'].sum().sort_values(by='Location', ascending=False)
sns.barplot(x='Latitude', y='Location', hue='Location', data=dubai_Latitude_Location)
plt.title('Total Latitude by Location')
plt.xlabel('Latitude')
plt.ylabel('Location')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
